# %% [markdown]
# Following example shows:
# - complete graph with size 5 where the optimal intervention is on last 2 nodes
# - number of instances=3
# - number of runs for each method=10
# - number of time steps=10
#
# To replicate the plots (**Fig. 5, Supplemntary Fig. 4-7**) in the paper: change the above parameters according to the paper

# %%
from argparse import Namespace
import numpy as np
import matplotlib.pyplot as plt

from data import synthetic_instance, gen_dag
from run import run
from visualize import *

# %% [markdown]
# ### Generate synthetic instances

# %%
seed = 1
np.random.seed(seed)

# generate problem instantiation
nnodes = 30
sigma_square = np.ones(nnodes)
DAG_type = 'complete'

num_instances = 10
a_size = 5

problems = []
graph = gen_dag(nnodes=nnodes, DAG_type=DAG_type)
for _ in range(num_instances):
	problem = synthetic_instance(
		nnodes=nnodes, 
		DAG_type=DAG_type,
		std=True,
		sigma_square=sigma_square, 
		a_size=a_size,
		# a_target_nodes=[i+(nnodes-max(a_size,2)) for i in range(a_size)],
		a_target_nodes=np.random.randint(low=0, high=nnodes, size=a_size), 
		prefix_DAG=graph
		)
	problems.append(problem)

# %%
draw(
	problem.DAG, 
	colored_set = set(i for i in range(problem.nnodes) if problem.a_target[i]!=0), 
	affected_set=set().union(*[problem.DAG.descendants_of(i) for i in range(problem.nnodes) if problem.a_target[i]!=0]),
	)
# Out:
# there are no undirected edges
# plotting...

# %% [markdown]
# ### Run 5 methods

# %%
# options for testing
opts = Namespace(n=1, T=50, W=0, R=10, time=False)

# %%
acqs = ['greedy', 'maxv','cv', 'civ', 'civ','grad']
measure = [None, None, None, 'unif', 'ow', None]
known_variance = [False, True, True, True, True, True]
name = ['greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']
# acqs = ['grad']
# measure = [None]
# known_variance = [True]
# name = ['grad']

MSEs = []
As = []
Probs = []
Times = []
for i in range(num_instances):
	problem = problems[i]

	A = {}
	Prob = {}
	Time = {}
	
	opts.active = False
	A['passive'], Prob['passive'] = run(problem, opts)

	opts.active = True
	for a in range(len(acqs)):
		opts.acq = acqs[a]
		opts.measure = measure[a]
		opts.known_noise = known_variance[a]
		A[name[a]], Prob[name[a]] = run(problem, opts)

	print(f'Graph {i+1}')

	As.append(A)
	Probs.append(Prob)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.01it/s]
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# 100%|██████████| 10/10 [01:00<00:00,  6.07s/it]
#  90%|█████████ | 9/10 [00:11<00:01,  1.30s/it]
# Optimization fails...
# Iteration limit reached
# 2nd initialization (estimate) failed...
# 100%|██████████| 10/10 [00:13<00:00,  1.30s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Graph 1
# 100%|██████████| 10/10 [00:00<00:00, 11.44it/s]
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# 100%|██████████| 10/10 [01:00<00:00,  6.05s/it]
# 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# 100%|██████████| 10/10 [00:42<00:00,  4.23s/it]
# Graph 2
# 100%|██████████| 10/10 [00:00<00:00, 10.44it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# 100%|██████████| 10/10 [00:58<00:00,  5.87s/it]
#  20%|██        | 2/10 [00:02<00:08,  1.02s/it]
# Optimization fails...
# Iteration limit reached
# 2nd initialization (estimate) failed...
# 100%|██████████| 10/10 [00:11<00:00,  1.17s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.01it/s]
# 100%|██████████| 10/10 [00:17<00:00,  1.73s/it]
# 100%|██████████| 10/10 [00:42<00:00,  4.25s/it]
# Graph 3
# 100%|██████████| 10/10 [00:00<00:00, 11.29it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# 100%|██████████| 10/10 [00:57<00:00,  5.76s/it]
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# 100%|██████████| 10/10 [00:16<00:00,  1.63s/it]
# 100%|██████████| 10/10 [00:39<00:00,  3.97s/it]
# Graph 4
# 100%|██████████| 10/10 [00:00<00:00, 11.18it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]
# 100%|██████████| 10/10 [01:00<00:00,  6.04s/it]
#  70%|███████   | 7/10 [00:07<00:03,  1.16s/it]
# Optimization fails...
# Iteration limit reached
# 2nd initialization (estimate) failed...
# 100%|██████████| 10/10 [00:11<00:00,  1.18s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# 100%|██████████| 10/10 [00:17<00:00,  1.72s/it]
# 100%|██████████| 10/10 [00:41<00:00,  4.17s/it]
# Graph 5
# 100%|██████████| 10/10 [00:00<00:00, 11.27it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]
# 100%|██████████| 10/10 [01:00<00:00,  6.01s/it]
# 100%|██████████| 10/10 [00:11<00:00,  1.17s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.03it/s]
# 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
# 100%|██████████| 10/10 [00:41<00:00,  4.13s/it]
# Graph 6
# 100%|██████████| 10/10 [00:00<00:00, 11.19it/s]
# 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
# 100%|██████████| 10/10 [01:00<00:00,  6.05s/it]
#  30%|███       | 3/10 [00:03<00:07,  1.09s/it]
# Optimization fails...
# Iteration limit reached
# 2nd initialization (estimate) failed...
# 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
# 100%|██████████| 10/10 [00:10<00:00,  1.00s/it]
# 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# 100%|██████████| 10/10 [00:40<00:00,  4.03s/it]
# Graph 7
# 100%|██████████| 10/10 [00:00<00:00, 11.30it/s]
# 100%|██████████| 10/10 [00:10<00:00,  1.03s/it]
# 100%|██████████| 10/10 [00:58<00:00,  5.89s/it]
#  80%|████████  | 8/10 [00:08<00:02,  1.10s/it]
# Optimization fails...
# Iteration limit reached
# 1st initialization (last round) failed...
# 100%|██████████| 10/10 [00:11<00:00,  1.20s/it]
# 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# 100%|██████████| 10/10 [00:18<00:00,  1.84s/it]
# 100%|██████████| 10/10 [00:42<00:00,  4.22s/it]
# Graph 8
# 100%|██████████| 10/10 [00:00<00:00, 11.23it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.01it/s]
# 100%|██████████| 10/10 [00:57<00:00,  5.77s/it]
#  30%|███       | 3/10 [00:03<00:09,  1.31s/it]
# Optimization fails...
# Iteration limit reached
# 100%|██████████| 10/10 [00:12<00:00,  1.27s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]
# 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# 100%|██████████| 10/10 [00:44<00:00,  4.41s/it]
# Graph 9
# 100%|██████████| 10/10 [00:00<00:00, 11.22it/s]
# 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]
# 100%|██████████| 10/10 [00:58<00:00,  5.89s/it]
# 100%|██████████| 10/10 [00:11<00:00,  1.17s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# 100%|██████████| 10/10 [00:15<00:00,  1.59s/it]
# 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]
# Graph 10

# %% [markdown]
# ### Plot results

# %%
mu_MSEs = []
for i in range(num_instances):
    Prob = Probs[i]
    problem = problems[i]
    mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
    for r in range(opts.R):
        for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
            mse = []
            for prob in Prob[k][r]:
                errs = abs(np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target) - problem.a_target)
                mse.append(np.linalg.norm(np.concatenate(errs))**2)
            mu_mses[k].append(mse)
    mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
    mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
    std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
    plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
    plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||a_t^*-a^*||_2^2$ (log scale)')
# plt.title(f'square distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/mse-int-mean_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
#5 target nodes
mu_MSEs = []
for i in range(num_instances):
    Prob = Probs[i]
    problem = problems[i]
    mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
    for r in range(opts.R):
        for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
            mse = []
            for prob in Prob[k][r]:
                errs = abs(np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target) - problem.a_target)
                mse.append(np.linalg.norm(np.concatenate(errs))**2)
            mu_mses[k].append(mse)
    mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
    mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
    std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
    plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
    plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||a_t^*-a^*||_2^2$ (log scale)')
# plt.title(f'square distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/mse-int-mean_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
mu_MSEs = []
for i in range(num_instances):
	Prob = Probs[i]
	problem = problems[i]
	mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
	for r in range(opts.R):
		for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
			mse = []
			for prob in Prob[k][r]:
				errs = abs(np.dot(problem.A,np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target)) - problem.mu_target)
				mse.append(np.linalg.norm(np.concatenate(errs)) / np.linalg.norm(problem.mu_target))
			mu_mses[k].append(mse)
	mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
	mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
	std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
	plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
	plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'relative distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-rmse_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
#5 target nodes
mu_MSEs = []
for i in range(num_instances):
	Prob = Probs[i]
	problem = problems[i]
	mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
	for r in range(opts.R):
		for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
			mse = []
			for prob in Prob[k][r]:
				errs = abs(np.dot(problem.A,np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target)) - problem.mu_target)
				mse.append(np.linalg.norm(np.concatenate(errs)) / np.linalg.norm(problem.mu_target))
			mu_mses[k].append(mse)
	mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
	mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
	std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
	plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
	plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'relative distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-rmse_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
plt.clf()
fig, ax = plt.subplots(1,1,figsize=(4,4))
plt.rcParams.update({'font.size': 12})

data = []
for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
	data.append([np.array(mu_MSEs[i][k]).mean(axis=0)[-1] for i in range(num_instances)])
bplots = plt.boxplot(data, labels=['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad'], patch_artist=False);

# fill with colors
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']

for patch, color in zip(bplots['boxes'], colors):
	# patch.set_facecolor(color)
	patch.set(color=color, linewidth=1.5)
	
for line, color in zip(bplots['medians'], colors):
	# patch.set_facecolor(color)
	line.set(color=color, linewidth=1.5)

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'time step {opts.T}')
plt.yscale('log')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-err-lastround_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
#5 target nodes
plt.clf()
fig, ax = plt.subplots(1,1,figsize=(4,4))
plt.rcParams.update({'font.size': 12})

data = []
for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
	data.append([np.array(mu_MSEs[i][k]).mean(axis=0)[-1] for i in range(num_instances)])
bplots = plt.boxplot(data, labels=['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad'], patch_artist=False);

# fill with colors
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']

for patch, color in zip(bplots['boxes'], colors):
	# patch.set_facecolor(color)
	patch.set(color=color, linewidth=1.5)
	
for line, color in zip(bplots['medians'], colors):
	# patch.set_facecolor(color)
	line.set(color=color, linewidth=1.5)

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'time step {opts.T}')
plt.yscale('log')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-err-lastround_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %% [markdown]
# ### 5 Random Nodes

# %%
#5 target nodes
mu_MSEs = []
for i in range(num_instances):
    Prob = Probs[i]
    problem = problems[i]
    mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
    for r in range(opts.R):
        for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
            mse = []
            for prob in Prob[k][r]:
                errs = abs(np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target) - problem.a_target)
                mse.append(np.linalg.norm(np.concatenate(errs))**2)
            mu_mses[k].append(mse)
    mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
    mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
    std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
    plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
    plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||a_t^*-a^*||_2^2$ (log scale)')
# plt.title(f'square distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/mse-int-mean_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
#5 target nodes
mu_MSEs = []
for i in range(num_instances):
	Prob = Probs[i]
	problem = problems[i]
	mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']}
	for r in range(opts.R):
		for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
			mse = []
			for prob in Prob[k][r]:
				errs = abs(np.dot(problem.A,np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target)) - problem.mu_target)
				mse.append(np.linalg.norm(np.concatenate(errs)) / np.linalg.norm(problem.mu_target))
			mu_mses[k].append(mse)
	mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']
markers = ['^', 'o', 'o', 'o', 's', 's', 's']
linestyles = ['--','--','--', '--','-', '-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']):
	mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
	std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
	plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
	plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'relative distance to target mean')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-rmse_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

# %%
#5 target nodes
plt.clf()
fig, ax = plt.subplots(1,1,figsize=(4,4))
plt.rcParams.update({'font.size': 12})

data = []
for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow', 'grad']:
	data.append([np.array(mu_MSEs[i][k]).mean(axis=0)[-1] for i in range(num_instances)])
bplots = plt.boxplot(data, labels=['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW', 'Grad'], patch_artist=False);

# fill with colors
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF', 'red']

for patch, color in zip(bplots['boxes'], colors):
	# patch.set_facecolor(color)
	patch.set(color=color, linewidth=1.5)
	
for line, color in zip(bplots['medians'], colors):
	# patch.set_facecolor(color)
	line.set(color=color, linewidth=1.5)

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
# plt.title(f'time step {opts.T}')
plt.yscale('log')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-err-lastround_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')
